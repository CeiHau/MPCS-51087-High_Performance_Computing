# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
mse = pd.read_csv('mse.csv', header = None)

# %%
# Out:
#        0         1
# 1      1  0.210962
# 2      2  0.217991
# 3      3  0.157383
# 4      4  0.102931
# 5      5  0.139107
# ...   ..       ...
# 59995  5  0.035125
# 59996  6  0.063969
# 59997  7  0.002048
# 59998  8  0.013441
# 59999  9  0.077677
#
# [59999 rows x 2 columns]

# %%
x = np.array(range(60000))
x
# Out:
# array([    0,     1,     2, ..., 59997, 59998, 59999])

# %%
y = np.array(mse[1])
y
# Out:
# array([0.14300206, 0.21096229, 0.21799099, ..., 0.00204824, 0.0134411 ,
#        0.07767706])

# %%
fig = plt.figure(dpi = 300)
plt.xlabel('training samples', fontsize=12)
plt.ylabel('Cost', fontsize=12)
plt.scatter(x[:], y[:], s = 0.3)
plt.show()
