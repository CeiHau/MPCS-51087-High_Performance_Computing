# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D

# %%
from numpy import genfromtxt
my_data = genfromtxt('project1/initialized.csv', delimiter=',')

# %%
def draw(file_name):
    my_data = genfromtxt('project1/' + file_name, delimiter=',')
    new_data=  my_data[:,:-1]
    plt.imshow(new_data, cmap='hot', interpolation='nearest')
    plt.show()

# %%
draw('initialized.csv')

# %%
draw('half.csv')

# %%
draw('end.csv')
